# %%
# ----------------------------
# 1. Imports & Data Loading
# ----------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import time
from datetime import datetime

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

from skactiveml.classifier import SklearnClassifier
from skactiveml.pool import UncertaintySampling, RandomSampling
from skactiveml.utils import MISSING_LABEL

# Load dataset
data = pd.read_csv("../data/simulation_security_labels_n-1.csv")
data["status_binary"] = data["status"].map({"secure": 1, "insecure": 0})

# Drop unused columns
columns_to_drop = [
    "timestamp", "status", "status_binary",
    "max_line_loading_percent_basecase",
    "min_bus_voltage_pu_basecase",
    "max_bus_voltage_pu_basecase",
    "max_line_loading_percent_contingency",
    "min_bus_voltage_pu_contingency",
    "max_bus_voltage_pu_contingency"
]
X = data.drop(columns=columns_to_drop, axis=1, errors="ignore")
y = data["status_binary"]

# %%
# ----------------------------
# 2. Split into Pool and Validation Set
# ----------------------------
test_size = 0.1
X_pool, X_val, y_pool, y_val = train_test_split(X, y, test_size=test_size, random_state=42)

# # Manual time split
# split_index = int(0.9 * len(X))
# X_pool = X.iloc[:split_index]
# y_pool = y.iloc[:split_index]
# X_val = X.iloc[split_index:]
# y_val = y.iloc[split_index:]

# %%
# ----------------------------
# 3. Active Learning Function (skactiveml-based)
# ----------------------------

initial_size = 100
batch_size = 50
iterations = 40
def run_active_learning_skactiveml(X_pool, y_pool, X_val, y_val,
                                   initial_size=initial_size, batch_size=batch_size,
                                   iterations=iterations, strategy_type="uncertainty"):
    # Define base model
    base_model = RandomForestClassifier(n_estimators=100, random_state=42)
    model = SklearnClassifier(estimator=base_model)

    # Initialize strategy
    if strategy_type == "uncertainty":
        strategy = UncertaintySampling()
    elif strategy_type == "random":
        strategy = RandomSampling()
    elif strategy_type == "entropy":
        strategy = UncertaintySampling(method="entropy")
    elif strategy_type == "margin":
        strategy = UncertaintySampling(method="margin_sampling")
    else:
        raise ValueError("Invalid strategy_type")

    # Create initial labeled/unlabeled mask
    y_train = np.full(len(X_pool), MISSING_LABEL)
    initial_idx = np.random.choice(range(len(X_pool)), size=initial_size, replace=False)
    y_train[initial_idx] = y_pool.iloc[initial_idx]

    accuracies = []

    for i in range(iterations):
        model.fit(X_pool, y_train)
        y_pred = model.predict(X_val)
        acc = accuracy_score(y_val, y_pred)
        accuracies.append(acc)
        print(f"📈 Iteration {i+1} [{strategy_type}] - Accuracy: {acc:.4f}")

        # Query new samples – conditional logic based on strategy
        # if strategy_type == "uncertainty":
        if strategy_type in ["uncertainty", "entropy", "margin"]:
            query_idx, utilities = strategy.query(
                X_pool, y=y_train, clf=model,
                batch_size=batch_size, return_utilities=True
            )
        else:  # random sampling does NOT take clf
            query_idx = strategy.query(
                X_pool, y=y_train,
                batch_size=batch_size
            )

        # Label newly queried samples
        y_train[query_idx] = y_pool.iloc[query_idx]

    return accuracies

# %%
# ----------------------------
# 4. Run Active Learning & Random Sampling
# ----------------------------
start_time = time.time()

acc_active = run_active_learning_skactiveml(X_pool.copy(), y_pool.copy(), X_val, y_val, strategy_type="uncertainty")
acc_random = run_active_learning_skactiveml(X_pool.copy(), y_pool.copy(), X_val, y_val, strategy_type="random")
acc_entropy = run_active_learning_skactiveml(X_pool.copy(), y_pool.copy(), X_val, y_val, strategy_type="entropy")
acc_margin = run_active_learning_skactiveml(X_pool.copy(), y_pool.copy(), X_val, y_val, strategy_type="margin")

end_time = time.time()
# Out:
# 📈 Iteration 1 [uncertainty] - Accuracy: 0.8244
# 📈 Iteration 2 [uncertainty] - Accuracy: 0.8803
# 📈 Iteration 3 [uncertainty] - Accuracy: 0.8883
# 📈 Iteration 4 [uncertainty] - Accuracy: 0.9054
# 📈 Iteration 5 [uncertainty] - Accuracy: 0.9042
# 📈 Iteration 6 [uncertainty] - Accuracy: 0.9042
# 📈 Iteration 7 [uncertainty] - Accuracy: 0.9111
# 📈 Iteration 8 [uncertainty] - Accuracy: 0.9042
# 📈 Iteration 9 [uncertainty] - Accuracy: 0.9202
# 📈 Iteration 10 [uncertainty] - Accuracy: 0.9202
# 📈 Iteration 11 [uncertainty] - Accuracy: 0.9259
# 📈 Iteration 12 [uncertainty] - Accuracy: 0.9270
# 📈 Iteration 13 [uncertainty] - Accuracy: 0.9304
# 📈 Iteration 14 [uncertainty] - Accuracy: 0.9316
# 📈 Iteration 15 [uncertainty] - Accuracy: 0.9327
# 📈 Iteration 16 [uncertainty] - Accuracy: 0.9282
# 📈 Iteration 17 [uncertainty] - Accuracy: 0.9327
# 📈 Iteration 18 [uncertainty] - Accuracy: 0.9236
# 📈 Iteration 19 [uncertainty] - Accuracy: 0.9304
# 📈 Iteration 20 [uncertainty] - Accuracy: 0.9259
# 📈 Iteration 21 [uncertainty] - Accuracy: 0.9350
# 📈 Iteration 22 [uncertainty] - Accuracy: 0.9327
# 📈 Iteration 23 [uncertainty] - Accuracy: 0.9418
# 📈 Iteration 24 [uncertainty] - Accuracy: 0.9407
# 📈 Iteration 25 [uncertainty] - Accuracy: 0.9384
# 📈 Iteration 26 [uncertainty] - Accuracy: 0.9373
# 📈 Iteration 27 [uncertainty] - Accuracy: 0.9384
# 📈 Iteration 28 [uncertainty] - Accuracy: 0.9373
# 📈 Iteration 29 [uncertainty] - Accuracy: 0.9373
# 📈 Iteration 30 [uncertainty] - Accuracy: 0.9430
# 📈 Iteration 31 [uncertainty] - Accuracy: 0.9441
# 📈 Iteration 32 [uncertainty] - Accuracy: 0.9418
# 📈 Iteration 33 [uncertainty] - Accuracy: 0.9441
# 📈 Iteration 34 [uncertainty] - Accuracy: 0.9418
# 📈 Iteration 35 [uncertainty] - Accuracy: 0.9407
# 📈 Iteration 36 [uncertainty] - Accuracy: 0.9384
# 📈 Iteration 37 [uncertainty] - Accuracy: 0.9430
# 📈 Iteration 38 [uncertainty] - Accuracy: 0.9407
# 📈 Iteration 39 [uncertainty] - Accuracy: 0.9475
# 📈 Iteration 40 [uncertainty] - Accuracy: 0.9464
# 📈 Iteration 1 [random] - Accuracy: 0.8449
# 📈 Iteration 2 [random] - Accuracy: 0.8563
# 📈 Iteration 3 [random] - Accuracy: 0.8791
# 📈 Iteration 4 [random] - Accuracy: 0.8700
# 📈 Iteration 5 [random] - Accuracy: 0.8666
# 📈 Iteration 6 [random] - Accuracy: 0.8734
# 📈 Iteration 7 [random] - Accuracy: 0.8814
# 📈 Iteration 8 [random] - Accuracy: 0.8734
# 📈 Iteration 9 [random] - Accuracy: 0.8734
# 📈 Iteration 10 [random] - Accuracy: 0.8712
# 📈 Iteration 11 [random] - Accuracy: 0.8655
# 📈 Iteration 12 [random] - Accuracy: 0.8723
# 📈 Iteration 13 [random] - Accuracy: 0.8712
# 📈 Iteration 14 [random] - Accuracy: 0.8769
# 📈 Iteration 15 [random] - Accuracy: 0.8757
# 📈 Iteration 16 [random] - Accuracy: 0.8769
# 📈 Iteration 17 [random] - Accuracy: 0.8837
# 📈 Iteration 18 [random] - Accuracy: 0.8803
# 📈 Iteration 19 [random] - Accuracy: 0.8769
# 📈 Iteration 20 [random] - Accuracy: 0.8757
# 📈 Iteration 21 [random] - Accuracy: 0.8746
# 📈 Iteration 22 [random] - Accuracy: 0.8848
# 📈 Iteration 23 [random] - Accuracy: 0.8883
# 📈 Iteration 24 [random] - Accuracy: 0.8803
# 📈 Iteration 25 [random] - Accuracy: 0.8917
# 📈 Iteration 26 [random] - Accuracy: 0.8997
# 📈 Iteration 27 [random] - Accuracy: 0.9008
# 📈 Iteration 28 [random] - Accuracy: 0.8997
# 📈 Iteration 29 [random] - Accuracy: 0.9019
# 📈 Iteration 30 [random] - Accuracy: 0.9031
# 📈 Iteration 31 [random] - Accuracy: 0.9065
# 📈 Iteration 32 [random] - Accuracy: 0.9076
# 📈 Iteration 33 [random] - Accuracy: 0.9019
# 📈 Iteration 34 [random] - Accuracy: 0.9065
# 📈 Iteration 35 [random] - Accuracy: 0.9031
# 📈 Iteration 36 [random] - Accuracy: 0.9042
# 📈 Iteration 37 [random] - Accuracy: 0.9076
# 📈 Iteration 38 [random] - Accuracy: 0.9099
# 📈 Iteration 39 [random] - Accuracy: 0.9054
# 📈 Iteration 40 [random] - Accuracy: 0.9145
# 📈 Iteration 1 [entropy] - Accuracy: 0.8518
# 📈 Iteration 2 [entropy] - Accuracy: 0.8734
# 📈 Iteration 3 [entropy] - Accuracy: 0.8769
# 📈 Iteration 4 [entropy] - Accuracy: 0.8803
# 📈 Iteration 5 [entropy] - Accuracy: 0.8917
# 📈 Iteration 6 [entropy] - Accuracy: 0.8928
# 📈 Iteration 7 [entropy] - Accuracy: 0.8997
# 📈 Iteration 8 [entropy] - Accuracy: 0.9179
# 📈 Iteration 9 [entropy] - Accuracy: 0.9145
# 📈 Iteration 10 [entropy] - Accuracy: 0.9213
# 📈 Iteration 11 [entropy] - Accuracy: 0.9111
# 📈 Iteration 12 [entropy] - Accuracy: 0.9145
# 📈 Iteration 13 [entropy] - Accuracy: 0.9156
# 📈 Iteration 14 [entropy] - Accuracy: 0.9202
# 📈 Iteration 15 [entropy] - Accuracy: 0.9270
# 📈 Iteration 16 [entropy] - Accuracy: 0.9225
# 📈 Iteration 17 [entropy] - Accuracy: 0.9316
# 📈 Iteration 18 [entropy] - Accuracy: 0.9282
# 📈 Iteration 19 [entropy] - Accuracy: 0.9327
# 📈 Iteration 20 [entropy] - Accuracy: 0.9350
# 📈 Iteration 21 [entropy] - Accuracy: 0.9384
# 📈 Iteration 22 [entropy] - Accuracy: 0.9510
# 📈 Iteration 23 [entropy] - Accuracy: 0.9384
# 📈 Iteration 24 [entropy] - Accuracy: 0.9361
# 📈 Iteration 25 [entropy] - Accuracy: 0.9418
# 📈 Iteration 26 [entropy] - Accuracy: 0.9384
# 📈 Iteration 27 [entropy] - Accuracy: 0.9464
# 📈 Iteration 28 [entropy] - Accuracy: 0.9464
# 📈 Iteration 29 [entropy] - Accuracy: 0.9453
# 📈 Iteration 30 [entropy] - Accuracy: 0.9521
# 📈 Iteration 31 [entropy] - Accuracy: 0.9475
# 📈 Iteration 32 [entropy] - Accuracy: 0.9464
# 📈 Iteration 33 [entropy] - Accuracy: 0.9464
# 📈 Iteration 34 [entropy] - Accuracy: 0.9384
# 📈 Iteration 35 [entropy] - Accuracy: 0.9464
# 📈 Iteration 36 [entropy] - Accuracy: 0.9464
# 📈 Iteration 37 [entropy] - Accuracy: 0.9510
# 📈 Iteration 38 [entropy] - Accuracy: 0.9498
# 📈 Iteration 39 [entropy] - Accuracy: 0.9453
# 📈 Iteration 40 [entropy] - Accuracy: 0.9453
# 📈 Iteration 1 [margin] - Accuracy: 0.8495
# 📈 Iteration 2 [margin] - Accuracy: 0.8563
# 📈 Iteration 3 [margin] - Accuracy: 0.8757
# 📈 Iteration 4 [margin] - Accuracy: 0.8757
# 📈 Iteration 5 [margin] - Accuracy: 0.8871
# 📈 Iteration 6 [margin] - Accuracy: 0.8814
# 📈 Iteration 7 [margin] - Accuracy: 0.8962
# 📈 Iteration 8 [margin] - Accuracy: 0.9076
# 📈 Iteration 9 [margin] - Accuracy: 0.9019
# 📈 Iteration 10 [margin] - Accuracy: 0.9099
# 📈 Iteration 11 [margin] - Accuracy: 0.9179
# 📈 Iteration 12 [margin] - Accuracy: 0.9225
# 📈 Iteration 13 [margin] - Accuracy: 0.9225
# 📈 Iteration 14 [margin] - Accuracy: 0.9259
# 📈 Iteration 15 [margin] - Accuracy: 0.9293
# 📈 Iteration 16 [margin] - Accuracy: 0.9247
# 📈 Iteration 17 [margin] - Accuracy: 0.9225
# 📈 Iteration 18 [margin] - Accuracy: 0.9259
# 📈 Iteration 19 [margin] - Accuracy: 0.9282
# 📈 Iteration 20 [margin] - Accuracy: 0.9350
# 📈 Iteration 21 [margin] - Accuracy: 0.9373
# 📈 Iteration 22 [margin] - Accuracy: 0.9339
# 📈 Iteration 23 [margin] - Accuracy: 0.9327
# 📈 Iteration 24 [margin] - Accuracy: 0.9407
# 📈 Iteration 25 [margin] - Accuracy: 0.9407
# 📈 Iteration 26 [margin] - Accuracy: 0.9441
# 📈 Iteration 27 [margin] - Accuracy: 0.9396
# 📈 Iteration 28 [margin] - Accuracy: 0.9510
# 📈 Iteration 29 [margin] - Accuracy: 0.9430
# 📈 Iteration 30 [margin] - Accuracy: 0.9418
# 📈 Iteration 31 [margin] - Accuracy: 0.9498
# 📈 Iteration 32 [margin] - Accuracy: 0.9441
# 📈 Iteration 33 [margin] - Accuracy: 0.9464
# 📈 Iteration 34 [margin] - Accuracy: 0.9430
# 📈 Iteration 35 [margin] - Accuracy: 0.9430
# 📈 Iteration 36 [margin] - Accuracy: 0.9487
# 📈 Iteration 37 [margin] - Accuracy: 0.9453
# 📈 Iteration 38 [margin] - Accuracy: 0.9487
# 📈 Iteration 39 [margin] - Accuracy: 0.9464
# 📈 Iteration 40 [margin] - Accuracy: 0.9510

# %%
# ----------------------------
# 5. Plot Comparison
# ----------------------------
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(range(1, iterations + 1), acc_active, label="Uncertainty", marker='o')
ax.plot(range(1, iterations + 1), acc_random, label="Random", linestyle='--', marker='s')
ax.plot(range(1, iterations + 1), acc_entropy, label="Entropy", linestyle='-.', marker='^')
ax.plot(range(1, iterations + 1), acc_margin, label="Margin", linestyle=':', marker='x')

ax.set_title("Validation Accuracy - Comparison of Sampling Strategies")
ax.set_xlabel("Iteration")
ax.set_ylabel("Validation Accuracy")
ax.legend()
ax.grid(True)
plt.tight_layout()

# %%
# ----------------------------
# 6. Save Comparison Plot & Prepare Metadata Entry & Append Row to CSV Table
# ----------------------------
# Save figure with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
plot_filename = f"../figures/active_vs_random_{timestamp}.png"
fig.savefig(plot_filename)
print(f"Plot saved as: {plot_filename}")

total_labeled = initial_size + iterations * batch_size

strategies = {
    "uncertainty": acc_active,
    "random": acc_random,
    "entropy": acc_entropy,
    "margin": acc_margin
}

table_path = "../tables/active_learning_runs.csv"

fieldnames = [
    "timestamp", "strategy_type", "iterations", "test_size", "initial_size",
    "batch_size", "total_labeled_samples", "accuracy_final",
    "accuracy_mean", "accuracy_std", "duration_sec"
]

file_exists = os.path.isfile(table_path)
with open(table_path, mode='a', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()

    for strategy_name, acc_list in strategies.items():
        run_data = {
            "timestamp": timestamp,
            "strategy_type": strategy_name,
            "iterations": iterations,
            "test_size": test_size,
            "initial_size": initial_size,
            "batch_size": batch_size,
            "total_labeled_samples": total_labeled,
            "accuracy_final": acc_list[-1],
            "accuracy_mean": np.mean(acc_list),
            "accuracy_std": np.std(acc_list),
            "duration_sec": round(end_time - start_time, 2)
        }
        writer.writerow(run_data)
# Out:
# Plot saved as: ../../figures/al_strategy_param_variations/al_manual_temporal_split/active_vs_random_20250515_143658.png
